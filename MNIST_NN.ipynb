# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
plt.matshow(X_train[63])

# %%
y_train[63]
# Out:
# 0

# %%
X_train_2 = X_train / 255
X_test_2 = X_test / 255

# %%
from keras.engine.training import optimizer
import seaborn as sns

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(10, activation = 'sigmoid')
])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(X_train_2, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2756 - accuracy: 0.9217
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1258 - accuracy: 0.9635
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0877 - accuracy: 0.9742
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0672 - accuracy: 0.9793
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0523 - accuracy: 0.9842

# %%
model.evaluate(X_test_2, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0806 - accuracy: 0.9762
# [0.08059138804674149, 0.9761999845504761]

# %%
y_predicted = model.predict(X_test_2)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
y_predicted_labels[:5]

cm = tf.math.confusion_matrix(labels = y_test,
                         predictions = y_predicted_labels)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot =True, fmt ='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(1000, activation = 'relu'),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(10, activation = 'sigmoid')
])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(X_train_2, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1807 - accuracy: 0.9450
# Epoch 2/5
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0778 - accuracy: 0.9758
# Epoch 3/5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0531 - accuracy: 0.9832
# Epoch 4/5
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0406 - accuracy: 0.9870
# Epoch 5/5
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0318 - accuracy: 0.9894

# %%
model.evaluate(X_test_2, y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0717 - accuracy: 0.9803
# [0.07165160775184631, 0.9803000092506409]

# %%
y_predicted = model.predict(X_test_2)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
y_predicted_labels[:5]

cm = tf.math.confusion_matrix(labels = y_test,
                         predictions = y_predicted_labels)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot =True, fmt ='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 313/313 [==============================] - 1s 4ms/step
# Text(95.72222222222221, 0.5, 'Truth')
